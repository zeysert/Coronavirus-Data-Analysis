# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Downloads/1586158536_all.csv")

# %%
df.head(10)
# Out:
#    region    places reporting cases  cases  deaths  \
# 0  Africa                   Algeria   1300     130
# 1  Africa                    Angola     10       2
# 2  Africa                     Benin     16       0
# 3  Africa                  Botswana      4       1
# 4  Africa              Burkina_Faso    302      16
# 5  Africa                   Burundi      3       0
# 6  Africa                  Cameroon    555       9
# 7  Africa                Cape_Verde      7       1
# 8  Africa  Central_African_Republic      9       0
# 9  Africa                      Chad      8       0
#
#   confirmed cases in the last 15 days
# 0                                1206
# 1                                  10
# 2                                  14
# 3                                   4
# 4                                 262
# 5                                   3
# 6                                 528
# 7                                   5
# 8                                   8
# ...

# %%
df.shape
# Out:
# (205, 5)

# %%
df.dtypes
# Out:
# region                                 object
# places reporting cases                 object
# cases                                   int64
# deaths                                  int64
# confirmed cases in the last 15 days    object
# dtype: object

# %%
type(df['cases'][0])
# Out:
# numpy.int64

# %%
type(df['deaths'][0])
# Out:
# numpy.int64

# %%
type(df['region'][0])
# Out:
# str

# %%
type(df['places reporting cases'][0])
# Out:
# str

# %%
type(df['confirmed cases in the last 15 days'][0])
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   region                               205 non-null    object
#  1   places reporting cases               205 non-null    object
#  2   cases                                205 non-null    int64
#  3   deaths                               205 non-null    int64
#  4   confirmed cases in the last 15 days  205 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.1+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df['cases'].value_counts()
# Out:
# 10      9
# 4       5
# 14      4
# 21      4
# 6       4
#        ..
# 277     1
# 159     1
# 3483    1
# 154     1
# 123     1
# Name: cases, Length: 160, dtype: int64

# %%
df['region'].value_counts().plot(kind = 'bar',figsize=(10,5))

# %%
df['places reporting cases'].value_counts().plot(kind = 'bar',figsize=(40,10))

# %%
top10 = df["places reporting cases"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
top10.plot(kind="bar")

# %%
df['places reporting cases'].value_counts().plot(kind = 'pie',figsize=(50,10))
